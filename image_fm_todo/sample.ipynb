# %%
import os
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

def list_images(dir_path, exts=(".png")):
    files = [p for p in glob.glob(os.path.join(dir_path, "*")) if os.path.splitext(p)[1].lower() in exts]
    return files

def show_random_images(dir_path, n=5, title=None):
    files = list_images(dir_path)
    k = min(n, len(files))
    sampled = random.sample(files, k) if len(files) >= k else files

    fig, axes = plt.subplots(1, k, figsize=(k * 3, 3))
    if k == 1:
        axes = [axes]
    for ax, path in zip(axes, sampled):
        img = Image.open(path)
        ax.imshow(img)
        ax.set_title(os.path.basename(path), fontsize=8)
        ax.axis('off')
    if title:
        fig.suptitle(title)
    plt.tight_layout()
    plt.show()

BASE = "/home/reproducepark/workspace/Diffusion-Assignment7-Flow"
DIR_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_cfg")
# DIR_NO_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_nocfg")

show_random_images(DIR_CFG, n=5, title="sampling_cfg")
# show_random_images(DIR_NO_CFG, n=5, title="sampling_nocfg")

# %%
# !python ./fid/measure_fid.py ./data/afhq/eval ./results/cfg_fm-11-28-222027/sampling_cfg
# Out:
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Calculating FID given paths ./data/afhq/eval and ./results/cfg_fm-11-28-222027/sampling_cfg...
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 17.27it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 16.02it/s]
# FID: 3.8049131259815017

# %%
import os
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

def list_images(dir_path, exts=(".png")):
    files = [p for p in glob.glob(os.path.join(dir_path, "*")) if os.path.splitext(p)[1].lower() in exts]
    return files

def show_random_images(dir_path, n=5, title=None):
    files = list_images(dir_path)
    k = min(n, len(files))
    sampled = random.sample(files, k) if len(files) >= k else files

    fig, axes = plt.subplots(1, k, figsize=(k * 3, 3))
    if k == 1:
        axes = [axes]
    for ax, path in zip(axes, sampled):
        img = Image.open(path)
        ax.imshow(img)
        ax.set_title(os.path.basename(path), fontsize=8)
        ax.axis('off')
    if title:
        fig.suptitle(title)
    plt.tight_layout()
    plt.show()

BASE = "/home/reproducepark/workspace/Diffusion-Assignment7-Flow"
DIR_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_cfg_10step")
# DIR_NO_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_nocfg")

show_random_images(DIR_CFG, n=5, title="sampling_cfg_10step")
# show_random_images(DIR_NO_CFG, n=5, title="sampling_nocfg")

# %%
# !python ./fid/measure_fid.py ./data/afhq/eval ./results/cfg_fm-11-28-222027/sampling_cfg_10step
# Out:
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Calculating FID given paths ./data/afhq/eval and ./results/cfg_fm-11-28-222027/sampling_cfg_10step...
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 17.37it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 16.55it/s]
# FID: 10.578328221371207

# %%
import os
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

def list_images(dir_path, exts=(".png")):
    files = [p for p in glob.glob(os.path.join(dir_path, "*")) if os.path.splitext(p)[1].lower() in exts]
    return files

def show_random_images(dir_path, n=5, title=None):
    files = list_images(dir_path)
    k = min(n, len(files))
    sampled = random.sample(files, k) if len(files) >= k else files

    fig, axes = plt.subplots(1, k, figsize=(k * 3, 3))
    if k == 1:
        axes = [axes]
    for ax, path in zip(axes, sampled):
        img = Image.open(path)
        ax.imshow(img)
        ax.set_title(os.path.basename(path), fontsize=8)
        ax.axis('off')
    if title:
        fig.suptitle(title)
    plt.tight_layout()
    plt.show()

BASE = "/home/reproducepark/workspace/Diffusion-Assignment7-Flow"
DIR_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_cfg_30step")
# DIR_NO_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_nocfg")

show_random_images(DIR_CFG, n=5, title="sampling_cfg_30step")
# show_random_images(DIR_NO_CFG, n=5, title="sampling_nocfg")

# %%
# !python ./fid/measure_fid.py ./data/afhq/eval ./results/cfg_fm-11-28-222027/sampling_cfg_30step
# Out:
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Calculating FID given paths ./data/afhq/eval and ./results/cfg_fm-11-28-222027/sampling_cfg_30step...
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 17.50it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 16.65it/s]
# FID: 6.08560877323858

# %%
import os
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

def list_images(dir_path, exts=(".png")):
    files = [p for p in glob.glob(os.path.join(dir_path, "*")) if os.path.splitext(p)[1].lower() in exts]
    return files

def show_random_images(dir_path, n=5, title=None):
    files = list_images(dir_path)
    k = min(n, len(files))
    sampled = random.sample(files, k) if len(files) >= k else files

    fig, axes = plt.subplots(1, k, figsize=(k * 3, 3))
    if k == 1:
        axes = [axes]
    for ax, path in zip(axes, sampled):
        img = Image.open(path)
        ax.imshow(img)
        ax.set_title(os.path.basename(path), fontsize=8)
        ax.axis('off')
    if title:
        fig.suptitle(title)
    plt.tight_layout()
    plt.show()

BASE = "/home/reproducepark/workspace/Diffusion-Assignment7-Flow"
DIR_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_cfg_40step")
# DIR_NO_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_nocfg")

show_random_images(DIR_CFG, n=5, title="sampling_cfg_40step")
# show_random_images(DIR_NO_CFG, n=5, title="sampling_nocfg")

# %%
# !python ./fid/measure_fid.py ./data/afhq/eval ./results/cfg_fm-11-28-222027/sampling_cfg_40step
# Out:
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Calculating FID given paths ./data/afhq/eval and ./results/cfg_fm-11-28-222027/sampling_cfg_40step...
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 17.64it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 16.30it/s]
# FID: 4.06055832106362

# %%
import os
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

def list_images(dir_path, exts=(".png")):
    files = [p for p in glob.glob(os.path.join(dir_path, "*")) if os.path.splitext(p)[1].lower() in exts]
    return files

def show_random_images(dir_path, n=5, title=None):
    files = list_images(dir_path)
    k = min(n, len(files))
    sampled = random.sample(files, k) if len(files) >= k else files

    fig, axes = plt.subplots(1, k, figsize=(k * 3, 3))
    if k == 1:
        axes = [axes]
    for ax, path in zip(axes, sampled):
        img = Image.open(path)
        ax.imshow(img)
        ax.set_title(os.path.basename(path), fontsize=8)
        ax.axis('off')
    if title:
        fig.suptitle(title)
    plt.tight_layout()
    plt.show()

BASE = "/home/reproducepark/workspace/Diffusion-Assignment7-Flow"
DIR_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_cfg_1step")
# DIR_NO_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_nocfg")

show_random_images(DIR_CFG, n=5, title="sampling_cfg_1step")
# show_random_images(DIR_NO_CFG, n=5, title="sampling_nocfg")

# %%
# !python ./fid/measure_fid.py ./data/afhq/eval ./results/cfg_fm-11-28-222027/sampling_cfg_1step
# Out:
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Calculating FID given paths ./data/afhq/eval and ./results/cfg_fm-11-28-222027/sampling_cfg_1step...
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 17.73it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 16.48it/s]
# FID: 46.71561347183962

# %%
import os
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

def list_images(dir_path, exts=(".png")):
    files = [p for p in glob.glob(os.path.join(dir_path, "*")) if os.path.splitext(p)[1].lower() in exts]
    return files

def show_random_images(dir_path, n=5, title=None):
    files = list_images(dir_path)
    k = min(n, len(files))
    sampled = random.sample(files, k) if len(files) >= k else files

    fig, axes = plt.subplots(1, k, figsize=(k * 3, 3))
    if k == 1:
        axes = [axes]
    for ax, path in zip(axes, sampled):
        img = Image.open(path)
        ax.imshow(img)
        ax.set_title(os.path.basename(path), fontsize=8)
        ax.axis('off')
    if title:
        fig.suptitle(title)
    plt.tight_layout()
    plt.show()

BASE = "/home/reproducepark/workspace/Diffusion-Assignment7-Flow"
DIR_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_cfg_2step")
# DIR_NO_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_nocfg")

show_random_images(DIR_CFG, n=5, title="sampling_cfg_2step")
# show_random_images(DIR_NO_CFG, n=5, title="sampling_nocfg")

# %%
# !python ./fid/measure_fid.py ./data/afhq/eval ./results/cfg_fm-11-28-222027/sampling_cfg_2step
# Out:
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Calculating FID given paths ./data/afhq/eval and ./results/cfg_fm-11-28-222027/sampling_cfg_2step...
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 17.40it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 16.53it/s]
# FID: 14.478324740705872

# %%
import os
import glob
import random
import matplotlib.pyplot as plt
from PIL import Image

def list_images(dir_path, exts=(".png")):
    files = [p for p in glob.glob(os.path.join(dir_path, "*")) if os.path.splitext(p)[1].lower() in exts]
    return files

def show_random_images(dir_path, n=5, title=None):
    files = list_images(dir_path)
    k = min(n, len(files))
    sampled = random.sample(files, k) if len(files) >= k else files

    fig, axes = plt.subplots(1, k, figsize=(k * 3, 3))
    if k == 1:
        axes = [axes]
    for ax, path in zip(axes, sampled):
        img = Image.open(path)
        ax.imshow(img)
        ax.set_title(os.path.basename(path), fontsize=8)
        ax.axis('off')
    if title:
        fig.suptitle(title)
    plt.tight_layout()
    plt.show()

BASE = "/home/reproducepark/workspace/Diffusion-Assignment7-Flow"
DIR_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_cfg_3step")
# DIR_NO_CFG = os.path.join(BASE, "image_fm_todo/results/cfg_fm-11-28-222027/sampling_nocfg")

show_random_images(DIR_CFG, n=5, title="sampling_cfg_3step")
# show_random_images(DIR_NO_CFG, n=5, title="sampling_nocfg")

# %%
# !python ./fid/measure_fid.py ./data/afhq/eval ./results/cfg_fm-11-28-222027/sampling_cfg_3step
# Out:
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Calculating FID given paths ./data/afhq/eval and ./results/cfg_fm-11-28-222027/sampling_cfg_3step...
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/reproducepark/anaconda3/envs/ddpm/lib/python3.10/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 24/24 [00:01<00:00, 17.48it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 16.58it/s]
# FID: 14.937616249240474
